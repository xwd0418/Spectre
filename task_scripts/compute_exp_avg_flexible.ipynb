# %%
import os, pickle, sys, torch, numpy as np


# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/flexible_models_larger_no_jittering"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/larger_flexible_models_3072dim"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW/"
# '/root/gurusmart/MorganFP_prediction/reproduce_previous_works/all_2d1d_datasets/entropy_radius_exps_on_2d1d_datasets'
# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_size_1/"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW_flexible_normal_hsqc/"
# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW_flexible_normal_hsqc_separate_embedding"
print_keys = [
    "test_mean_rank_1/",
    "test_mean_rank_5/",
    "test_mean_rank_10/",
    "test_mean_mean_rank",
    "test_mean_cos",
    "test_mean_f1", 
]

all_exps = os.listdir(table_path)
all_exps = sorted(all_exps)
# load pickles 
from collections import defaultdict
exp_name_to_key_to_results = defaultdict(lambda: defaultdict(list))
for exp in all_exps:
    # print(exp)
    if 'trial' in exp:
        trial_spelling = "trial"
    elif 'trail' in exp:
        trial_spelling = "trail"
        
    with open(f'{table_path}/{exp}/test_result.pkl', 'rb') as f:
        result = pickle.load(f)[0]
      

        
        for print_key in print_keys:
            for pickle_key in result:
                
                if print_key in pickle_key:
                    exp_name_to_key_to_results["_".join(exp.split(trial_spelling)[:-1])][pickle_key].append(result[pickle_key])
            # exp_name_to_key_to_results[exp][key].append(result[key])
            # print(key, result[key])
    
            
    
exp_name_to_key_to_results
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'r0_r6_': defaultdict(list,
#                          {'test_mean_rank_1/all_inputs': [0.5133694410324097,
#                            0.5132054090499878],
#                           'test_mean_rank_1/HSQC_H_NMR': [0.4602198302745819,
#                            0.45103347301483154],
#                           'test_mean_rank_1/HSQC_C_NMR': [0.5177985429763794,
#                            0.509186327457428],
#                           'test_mean_rank_1/only_hsqc': [0.43996062874794006,
#                            0.43971458077430725],
#                           'test_mean_rank_1/only_1d': [0.3106135129928589,
#                            0.30249345302581787],
#                           'test_mean_rank_1/only_H_NMR': [0.04035433009266853,
#                            0.045521654188632965],
#                           'test_mean_rank_1/only_C_NMR': [0.2375328093767166,
#                            0.2381889820098877],
#                           'test_mean_rank_5/all_inputs': [0.8254593014717102,
#                            0.8273457884788513],
#                           'test_mean_rank_5/HSQC_H_NMR': [0.7786253094673157,
#                            0.7765747904777527],
#                           'test_mean_rank_5/HSQC_C_NMR': [0.8229987025260925,
#                            0.8286581635475159],
#                           'test_mean_rank_5/only_hsqc': [0.7592683434486389,
#                            0.7596784830093384],
#                           'test_mean_rank_5/only_1d': [0.5913714170455933,
#                            0.5926017165184021],
#                           'test_mean_rank_5/only_H_NMR': [0.13082349300384521,
#                            0.1317257285118103],
#                           'test_mean_rank_5/only_C_NMR': [0.49712926149368286,
#                            0.4937663972377777],
#                           'test_mean_rank_10/all_inputs': [0.8954232335090637,
#                            0.8973917365074158],
#                           'test_mean_rank_10/HSQC_H_NMR': [0.8548228144645691,
#                            0.8513779640197754],
#                           'test_mean_rank_10/HSQC_C_NMR': [0.8924704790115356,
#                            0.8961614370346069],
#                           'test_mean_rank_10/only_hsqc': [0.8349737524986267,
#                            0.8360400199890137],
#                           'test_mean_rank_10/only_1d': [0.6887302994728088,
#                            0.6948819160461426],
#                           'test_mean_rank_10/only_H_NMR': [0.18553149700164795,
#                            0.18922244012355804],
#                           'test_mean_rank_10/only_C_NMR': [0.589648962020874,
#                            0.5975229740142822],
#                           'test_mean_mean_rank/all_inputs': [175.77395629882812,
#                            288.9437255859375],
#                           'test_mean_mean_rank/HSQC_H_NMR': [306.49639892578125,
#                            575.4251708984375],
#                           'test_mean_mean_rank/HSQC_C_NMR': [183.6773223876953,
#                            268.7620544433594],
#                           'test_mean_mean_rank/only_hsqc': [260.5087890625,
#                            585.0270385742188],
#                           'test_mean_mean_rank/only_1d': [937.6328735351562,
#                            877.1419677734375],
#                           'test_mean_mean_rank/only_H_NMR': [12040.2490234375,
#                            12631.955078125],
#                           'test_mean_mean_rank/only_C_NMR': [3051.30126953125,
#                            2631.931640625],
#                           'test_mean_cos/all_inputs': [0.8900575637817383,
#                            0.8889023065567017],
#                           'test_mean_cos/HSQC_H_NMR': [0.8713729381561279,
#                            0.8697242140769958],
#                           'test_mean_cos/HSQC_C_NMR': [0.889945387840271,
#                            0.8879643082618713],
#                           'test_mean_cos/only_hsqc': [0.8616657853126526,
#                            0.8615590333938599],
#                           'test_mean_cos/only_1d': [0.7920950651168823,
#                            0.7911030650138855],
#                           'test_mean_cos/only_H_NMR': [0.5711424350738525,
#                            0.5720130205154419],
#                           'test_mean_cos/only_C_NMR': [0.7516952157020569,
#                            0.7509496808052063],
#                           'test_mean_f1/all_inputs': [0.904144823551178,
#                            0.9032203555107117],
#                           'test_mean_f1/HSQC_H_NMR': [0.8888716697692871,
#                            0.8872760534286499],
#                           'test_mean_f1/HSQC_C_NMR': [0.9039217829704285,
#                            0.9025087356567383],
#                           'test_mean_f1/only_hsqc': [0.8801912665367126,
#                            0.8797782063484192],
#                           'test_mean_f1/only_1d': [0.8128260374069214,
#                            0.8120010495185852],
#                           'test_mean_f1/only_H_NMR': [0.5805022120475769,
#                            0.582880437374115],
#                           'test_mean_f1/only_C_NMR': [0.7801082730293274,
#                            0.7792224287986755]})})

# %%
avg_results = {}
for exp_name, key_to_results in exp_name_to_key_to_results.items():
    avg_results[exp_name] = {key: (np.mean(val), np.std(val)) for key, val in key_to_results.items()}
avg_results
# Out:
# {'r0_r6_': {'test_mean_rank_1/all_inputs': (np.float64(0.5132874250411987),
#    np.float64(8.20159912109375e-05)),
#   'test_mean_rank_1/HSQC_H_NMR': (np.float64(0.4556266516447067),
#    np.float64(0.004593178629875183)),
#   'test_mean_rank_1/HSQC_C_NMR': (np.float64(0.5134924352169037),
#    np.float64(0.004306107759475708)),
#   'test_mean_rank_1/only_hsqc': (np.float64(0.43983760476112366),
#    np.float64(0.00012302398681640625)),
#   'test_mean_rank_1/only_1d': (np.float64(0.3065534830093384),
#    np.float64(0.004060029983520508)),
#   'test_mean_rank_1/only_H_NMR': (np.float64(0.04293799214065075),
#    np.float64(0.002583662047982216)),
#   'test_mean_rank_1/only_C_NMR': (np.float64(0.23786089569330215),
#    np.float64(0.00032808631658554077)),
#   'test_mean_rank_5/all_inputs': (np.float64(0.8264025449752808),
#    np.float64(0.0009432435035705566)),
#   'test_mean_rank_5/HSQC_H_NMR': (np.float64(0.7776000499725342),
#    np.float64(0.0010252594947814941)),
#   'test_mean_rank_5/HSQC_C_NMR': (np.float64(0.8258284330368042),
#    np.float64(0.00282973051071167)),
#   'test_mean_rank_5/only_hsqc': (np.float64(0.7594734132289886),
#    np.float64(0.00020506978034973145)),
#   'test_mean_rank_5/only_1d': (np.float64(0.5919865667819977),
#    np.float64(0.0006151497364044189)),
#   'test_mean_rank_5/only_H_NMR': (np.float64(0.13127461075782776),
#    np.float64(0.00045111775398254395)),
#   'test_mean_rank_5/only_C_NMR': (np.float64(0.4954478293657303),
#    np.float64(0.0016814321279525757)),
#   'test_mean_rank_10/all_inputs': (np.float64(0.8964074850082397),
#    np.float64(0.0009842514991760254)),
#   'test_mean_rank_10/HSQC_H_NMR': (np.float64(0.8531003892421722),
#    np.float64(0.0017224252223968506)),
#   'test_mean_rank_10/HSQC_C_NMR': (np.float64(0.8943159580230713),
#    np.float64(0.0018454790115356445)),
#   'test_mean_rank_10/only_hsqc': (np.float64(0.8355068862438202),
#    np.float64(0.0005331337451934814)),
#   'test_mean_rank_10/only_1d': (np.float64(0.6918061077594757),
#    np.float64(0.00307580828666687)),
#   'test_mean_rank_10/only_H_NMR': (np.float64(0.187376968562603),
#    np.float64(0.0018454715609550476)),
#   'test_mean_rank_10/only_C_NMR': (np.float64(0.5935859680175781),
#    np.float64(0.0039370059967041016)),
#   'test_mean_mean_rank/all_inputs': (np.float64(232.3588409423828),
#    np.float64(56.58488464355469)),
#   'test_mean_mean_rank/HSQC_H_NMR': (np.float64(440.9607849121094),
#    np.float64(134.46438598632812)),
#   'test_mean_mean_rank/HSQC_C_NMR': (np.float64(226.21968841552734),
#    np.float64(42.54236602783203)),
#   'test_mean_mean_rank/only_hsqc': (np.float64(422.7679138183594),
#    np.float64(162.25912475585938)),
#   'test_mean_mean_rank/only_1d': (np.float64(907.3874206542969),
#    np.float64(30.245452880859375)),
#   'test_mean_mean_rank/only_H_NMR': (np.float64(12336.10205078125),
#    np.float64(295.85302734375)),
#   'test_mean_mean_rank/only_C_NMR': (np.float64(2841.616455078125),
#    np.float64(209.684814453125)),
#   'test_mean_cos/all_inputs': (np.float64(0.88947993516922),
#    np.float64(0.0005776286125183105)),
#   'test_mean_cos/HSQC_H_NMR': (np.float64(0.8705485761165619),
#    np.float64(0.00082436203956604)),
#   'test_mean_cos/HSQC_C_NMR': (np.float64(0.8889548480510712),
#    np.float64(0.000990539789199829)),
#   'test_mean_cos/only_hsqc': (np.float64(0.8616124093532562),
#    np.float64(5.3375959396362305e-05)),
#   'test_mean_cos/only_1d': (np.float64(0.7915990650653839),
#    np.float64(0.0004960000514984131)),
#   'test_mean_cos/only_H_NMR': (np.float64(0.5715777277946472),
#    np.float64(0.00043529272079467773)),
#   'test_mean_cos/only_C_NMR': (np.float64(0.7513224482536316),
#    np.float64(0.00037276744842529297)),
#   'test_mean_f1/all_inputs': (np.float64(0.9036825895309448),
#    np.float64(0.0004622340202331543)),
#   'test_mean_f1/HSQC_H_NMR': (np.float64(0.8880738615989685),
#    np.float64(0.0007978081703186035)),
#   'test_mean_f1/HSQC_C_NMR': (np.float64(0.9032152593135834),
#    np.float64(0.0007065236568450928)),
#   'test_mean_f1/only_hsqc': (np.float64(0.8799847364425659),
#    np.float64(0.00020653009414672852)),
#   'test_mean_f1/only_1d': (np.float64(0.8124135434627533),
#    np.float64(0.0004124939441680908)),
#   'test_mean_f1/only_H_NMR': (np.float64(0.581691324710846),
#    np.float64(0.001189112663269043)),
#   'test_mean_f1/only_C_NMR': (np.float64(0.7796653509140015),
#    np.float64(0.00044292211532592773))}}

# %%
for exp_name, key_to_results in avg_results['r0_r6_'].items():
    print(exp_name)
    mean, std = key_to_results
    print(f" {mean:.4f} +/- {std:.4f}")
    print()
# Out:
# test_mean_rank_1/all_inputs
#  0.5133 +/- 0.0001
#
# test_mean_rank_1/HSQC_H_NMR
#  0.4556 +/- 0.0046
#
# test_mean_rank_1/HSQC_C_NMR
#  0.5135 +/- 0.0043
#
# test_mean_rank_1/only_hsqc
#  0.4398 +/- 0.0001
#
# test_mean_rank_1/only_1d
#  0.3066 +/- 0.0041
#
# test_mean_rank_1/only_H_NMR
#  0.0429 +/- 0.0026
#
# test_mean_rank_1/only_C_NMR
#  0.2379 +/- 0.0003
#
# test_mean_rank_5/all_inputs
#  0.8264 +/- 0.0009
#
# test_mean_rank_5/HSQC_H_NMR
#  0.7776 +/- 0.0010
#
# test_mean_rank_5/HSQC_C_NMR
#  0.8258 +/- 0.0028
#
# test_mean_rank_5/only_hsqc
#  0.7595 +/- 0.0002
#
# test_mean_rank_5/only_1d
#  0.5920 +/- 0.0006
#
# test_mean_rank_5/only_H_NMR
#  0.1313 +/- 0.0005
#
# test_mean_rank_5/only_C_NMR
#  0.4954 +/- 0.0017
#
# test_mean_rank_10/all_inputs
#  0.8964 +/- 0.0010
#
# test_mean_rank_10/HSQC_H_NMR
#  0.8531 +/- 0.0017
#
# test_mean_rank_10/HSQC_C_NMR
#  0.8943 +/- 0.0018
#
# test_mean_rank_10/only_hsqc
#  0.8355 +/- 0.0005
#
# test_mean_rank_10/only_1d
#  0.6918 +/- 0.0031
#
# test_mean_rank_10/only_H_NMR
#  0.1874 +/- 0.0018
#
# test_mean_rank_10/only_C_NMR
#  0.5936 +/- 0.0039
#
# test_mean_mean_rank/all_inputs
#  232.3588 +/- 56.5849
#
# test_mean_mean_rank/HSQC_H_NMR
#  440.9608 +/- 134.4644
#
# test_mean_mean_rank/HSQC_C_NMR
#  226.2197 +/- 42.5424
#
# test_mean_mean_rank/only_hsqc
#  422.7679 +/- 162.2591
#
# test_mean_mean_rank/only_1d
#  907.3874 +/- 30.2455
#
# test_mean_mean_rank/only_H_NMR
#  12336.1021 +/- 295.8530
#
# test_mean_mean_rank/only_C_NMR
#  2841.6165 +/- 209.6848
#
# test_mean_cos/all_inputs
#  0.8895 +/- 0.0006
#
# test_mean_cos/HSQC_H_NMR
#  0.8705 +/- 0.0008
#
# test_mean_cos/HSQC_C_NMR
#  0.8890 +/- 0.0010
#
# test_mean_cos/only_hsqc
#  0.8616 +/- 0.0001
#
# test_mean_cos/only_1d
#  0.7916 +/- 0.0005
#
# test_mean_cos/only_H_NMR
#  0.5716 +/- 0.0004
#
# test_mean_cos/only_C_NMR
#  0.7513 +/- 0.0004
#
# test_mean_f1/all_inputs
#  0.9037 +/- 0.0005
#
# test_mean_f1/HSQC_H_NMR
#  0.8881 +/- 0.0008
#
# test_mean_f1/HSQC_C_NMR
#  0.9032 +/- 0.0007
#
# test_mean_f1/only_hsqc
#  0.8800 +/- 0.0002
#
# test_mean_f1/only_1d
#  0.8124 +/- 0.0004
#
# test_mean_f1/only_H_NMR
#  0.5817 +/- 0.0012
#
# test_mean_f1/only_C_NMR
#  0.7797 +/- 0.0004

# %%
numbers = np.array([0 , 0, 0])
numbers.mean(), numbers.std()
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
(torch.tensor([1,2,3]) == 0).all()
# Out:
# tensor(False)

# %%
key_to_results
# Out:
# (np.float64(0.7796653509140015), np.float64(0.00044292211532592773))

# %%
# for k in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
#     print(k)
#     mean,std = (avg_results['r0_r6_'][k]['test/mean_rank_1'])
#     print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")

# %%
# print in latex format
'''deprecated !!!'''
# for table_name in  ["all_inputs", "HSQC_H_NMR", "HSQC_C_NMR", "only_hsqc", "only_1d", "only_H_NMR",  "only_C_NMR"]:
for table_name in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
    print(table_name)
    # print("\n\n")
    # print ("\\begin{table}[h]")
    # print("\centering")
    # print('\\begin{tabular}{|c|c|c|c|c|c|}')
    # print("\hline")
    # print("Model Input & Rank-1$\\uparrow$ & Rank-5$\\uparrow$ & Mean Rank$\\downarrow$ & Cosine Sim$\\uparrow$ & F1-score$\\uparrow$\\\\")
    for exp_name, key_to_results in avg_results.items():
        name = exp_name
        if name[:2]=="FP":
            name = "R"+name.split(" ")[-1][-2]+" FP"
        print(f'{name.replace("_", " ")}', end="")
        for key, (mean, std) in key_to_results.items():
            if table_name!=key.split("/")[-1]: 
                continue
            # print(key)
            # if "test_mean_rank_1" in key or "test/mean_rank_5" in key:
            print(key)
            print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")
            # elif "test_mean_mean_rank" in key :
            #     print(f' & {val+1:.2f}', end="")
            # else:
            #     print(f' & {val:.4f}', end="")
        # print(" \\\\")
        # print("\hline")
        
        
    # print('\end{tabular}')
    # print("\caption{for " + f'{table_name.replace("_", " ")}'+ ", which entropy-based FP to use}")
    # print('\label{table_name}')
    # print('\end{table}')
# Out:
# all_inputs
# r0 r6 test_mean_rank_1/all_inputs
# 51.33\%\textpm0.01\%
# test_mean_rank_5/all_inputs
# 82.64\%\textpm0.09\%
# test_mean_rank_10/all_inputs
# 89.64\%\textpm0.10\%
# test_mean_mean_rank/all_inputs
# 23235.88\%\textpm5658.49\%
# test_mean_cos/all_inputs
# 88.95\%\textpm0.06\%
# test_mean_f1/all_inputs
# 90.37\%\textpm0.05\%
# only_1d
# r0 r6 test_mean_rank_1/only_1d
# 30.66\%\textpm0.41\%
# test_mean_rank_5/only_1d
# 59.20\%\textpm0.06\%
# test_mean_rank_10/only_1d
# 69.18\%\textpm0.31\%
# test_mean_mean_rank/only_1d
# 90738.74\%\textpm3024.55\%
# test_mean_cos/only_1d
# 79.16\%\textpm0.05\%
# test_mean_f1/only_1d
# 81.24\%\textpm0.04\%
# HSQC_C_NMR
# r0 r6 test_mean_rank_1/HSQC_C_NMR
# 51.35\%\textpm0.43\%
# test_mean_rank_5/HSQC_C_NMR
# 82.58\%\textpm0.28\%
# test_mean_rank_10/HSQC_C_NMR
# 89.43\%\textpm0.18\%
# test_mean_mean_rank/HSQC_C_NMR
# 22621.97\%\textpm4254.24\%
# test_mean_cos/HSQC_C_NMR
# 88.90\%\textpm0.10\%
# test_mean_f1/HSQC_C_NMR
# 90.32\%\textpm0.07\%
# HSQC_H_NMR
# r0 r6 test_mean_rank_1/HSQC_H_NMR
# 45.56\%\textpm0.46\%
# test_mean_rank_5/HSQC_H_NMR
# 77.76\%\textpm0.10\%
# test_mean_rank_10/HSQC_H_NMR
# 85.31\%\textpm0.17\%
# test_mean_mean_rank/HSQC_H_NMR
# 44096.08\%\textpm13446.44\%
# test_mean_cos/HSQC_H_NMR
# 87.05\%\textpm0.08\%
# test_mean_f1/HSQC_H_NMR
# 88.81\%\textpm0.08\%
# only_C_NMR
# r0 r6 test_mean_rank_1/only_C_NMR
# 23.79\%\textpm0.03\%
# test_mean_rank_5/only_C_NMR
# 49.54\%\textpm0.17\%
# test_mean_rank_10/only_C_NMR
# 59.36\%\textpm0.39\%
# test_mean_mean_rank/only_C_NMR
# 284161.65\%\textpm20968.48\%
# test_mean_cos/only_C_NMR
# 75.13\%\textpm0.04\%
# test_mean_f1/only_C_NMR
# 77.97\%\textpm0.04\%
# only_H_NMR
# r0 r6 test_mean_rank_1/only_H_NMR
# 4.29\%\textpm0.26\%
# test_mean_rank_5/only_H_NMR
# 13.13\%\textpm0.05\%
# test_mean_rank_10/only_H_NMR
# 18.74\%\textpm0.18\%
# test_mean_mean_rank/only_H_NMR
# 1233610.21\%\textpm29585.30\%
# test_mean_cos/only_H_NMR
# 57.16\%\textpm0.04\%
# test_mean_f1/only_H_NMR
# 58.17\%\textpm0.12\%
# only_hsqc
# r0 r6 test_mean_rank_1/only_hsqc
# 43.98\%\textpm0.01\%
# test_mean_rank_5/only_hsqc
# 75.95\%\textpm0.02\%
# test_mean_rank_10/only_hsqc
# 83.55\%\textpm0.05\%
# test_mean_mean_rank/only_hsqc
# 42276.79\%\textpm16225.91\%
# test_mean_cos/only_hsqc
# 86.16\%\textpm0.01\%
# test_mean_f1/only_hsqc
# 88.00\%\textpm0.02\%
