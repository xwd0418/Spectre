# %%
import os, pickle, sys, torch, numpy as np


# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/flexible_models_larger_no_jittering"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/larger_flexible_models_3072dim"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW/"
# '/root/gurusmart/MorganFP_prediction/reproduce_previous_works/all_2d1d_datasets/entropy_radius_exps_on_2d1d_datasets'
# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_size_1/"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW_flexible_normal_hsqc/"
# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_flexible_MW_flexible_normal_hsqc_separate_embedding"
print_keys = [
    "test_mean_rank_1/",
    "test_mean_rank_5/",
    "test_mean_rank_10/",
    "test_mean_mean_rank",
    "test_mean_cos",
    "test_mean_f1", 
]

all_exps = os.listdir(table_path)
all_exps = sorted(all_exps)
# load pickles 
from collections import defaultdict
exp_name_to_key_to_results = defaultdict(lambda: defaultdict(list))
for exp in all_exps:
    if "16384" not in exp:
        continue
    # print(exp)
    if 'trial' in exp:
        trial_spelling = "trial"
    elif 'trail' in exp:
        trial_spelling = "trail"
        
    with open(f'{table_path}/{exp}/test_result.pkl', 'rb') as f:
        result = pickle.load(f)[0]
      

        
        for print_key in print_keys:
            for pickle_key in result:
                
                if print_key in pickle_key:
                    exp_name_to_key_to_results["_".join(exp.split(trial_spelling)[:-1])][pickle_key].append(result[pickle_key])
            # exp_name_to_key_to_results[exp][key].append(result[key])
            # print(key, result[key])
    
            
    
exp_name_to_key_to_results
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'r6_16384_': defaultdict(list,
#                          {'test_mean_rank_1/all_inputs': [0.2824803292751312,
#                            0.285843163728714,
#                            0.28018373250961304],
#                           'test_mean_rank_1/HSQC_H_NMR': [0.26517388224601746,
#                            0.2643536627292633,
#                            0.26140090823173523],
#                           'test_mean_rank_1/HSQC_C_NMR': [0.28461286425590515,
#                            0.28830379247665405,
#                            0.28067585825920105],
#                           'test_mean_rank_1/only_hsqc': [0.25262466073036194,
#                            0.26140090823173523,
#                            0.2553313672542572],
#                           'test_mean_rank_1/only_1d': [0.16978345811367035,
#                            0.1759350448846817,
#                            0.17093175649642944],
#                           'test_mean_rank_1/only_H_NMR': [0.027066929265856743,
#                            0.029773622751235962,
#                            0.02657480351626873],
#                           'test_mean_rank_1/only_C_NMR': [0.1449311077594757,
#                            0.1488681137561798,
#                            0.14452099800109863],
#                           'test_mean_rank_5/all_inputs': [0.6527230739593506,
#                            0.6475557684898376,
#                            0.6455872654914856],
#                           'test_mean_rank_5/HSQC_H_NMR': [0.6264764070510864,
#                            0.6177821755409241,
#                            0.6235235929489136],
#                           'test_mean_rank_5/HSQC_C_NMR': [0.6546915769577026,
#                            0.6508365869522095,
#                            0.6514107584953308],
#                           'test_mean_rank_5/only_hsqc': [0.6250820159912109,
#                            0.6222112774848938,
#                            0.6197506785392761],
#                           'test_mean_rank_5/only_1d': [0.4174048602581024,
#                            0.4131397604942322,
#                            0.4122375249862671],
#                           'test_mean_rank_5/only_H_NMR': [0.08341535180807114,
#                            0.08489172905683517,
#                            0.08275918662548065],
#                           'test_mean_rank_5/only_C_NMR': [0.3597441017627716,
#                            0.3531824052333832,
#                            0.35843175649642944],
#                           'test_mean_rank_10/all_inputs': [0.7705052495002747,
#                            0.7614009380340576,
#                            0.7638615369796753],
#                           'test_mean_rank_10/HSQC_H_NMR': [0.7450787425041199,
#                            0.741797924041748,
#                            0.7372867465019226],
#                           'test_mean_rank_10/HSQC_C_NMR': [0.7760826945304871,
#                            0.7641075849533081,
#                            0.7660760879516602],
#                           'test_mean_rank_10/only_hsqc': [0.7361384630203247,
#                            0.7376148104667664,
#                            0.7314632534980774],
#                           'test_mean_rank_10/only_1d': [0.5347769260406494,
#                            0.5287893414497375,
#                            0.523047924041748],
#                           'test_mean_rank_10/only_H_NMR': [0.13074147701263428,
#                            0.12942913174629211,
#                            0.127542644739151],
#                           'test_mean_rank_10/only_C_NMR': [0.4618602395057678,
#                            0.4620242714881897,
#                            0.46079397201538086],
#                           'test_mean_mean_rank/all_inputs': [301.197998046875,
#                            483.03436279296875,
#                            485.4952392578125],
#                           'test_mean_mean_rank/HSQC_H_NMR': [459.4949951171875,
#                            568.2447509765625,
#                            693.4666748046875],
#                           'test_mean_mean_rank/HSQC_C_NMR': [300.2973937988281,
#                            402.2249755859375,
#                            452.9450378417969],
#                           'test_mean_mean_rank/only_hsqc': [472.61358642578125,
#                            521.8809814453125,
#                            592.3064575195312],
#                           'test_mean_mean_rank/only_1d': [1471.980224609375,
#                            1781.0145263671875,
#                            1436.87890625],
#                           'test_mean_mean_rank/only_H_NMR': [18785.09765625,
#                            18931.07421875,
#                            19187.908203125],
#                           'test_mean_mean_rank/only_C_NMR': [3598.740234375,
#                            3998.78662109375,
#                            3550.3896484375],
#                           'test_mean_cos/all_inputs': [0.6880291104316711,
#                            0.6892370581626892,
#                            0.6880836486816406],
#                           'test_mean_cos/HSQC_H_NMR': [0.678200364112854,
#                            0.6792276501655579,
#                            0.6786187887191772],
#                           'test_mean_cos/HSQC_C_NMR': [0.688575267791748,
#                            0.6895161271095276,
#                            0.6886192560195923],
#                           'test_mean_cos/only_hsqc': [0.6715890765190125,
#                            0.6724187731742859,
#                            0.6705821752548218],
#                           'test_mean_cos/only_1d': [0.6047701835632324,
#                            0.6064497828483582,
#                            0.6038526296615601],
#                           'test_mean_cos/only_H_NMR': [0.4231610596179962,
#                            0.4234142005443573,
#                            0.4216133952140808],
#                           'test_mean_cos/only_C_NMR': [0.5795352458953857,
#                            0.5788275599479675,
#                            0.5764995217323303],
#                           'test_mean_f1/all_inputs': [0.6983940601348877,
#                            0.6995210647583008,
#                            0.6975672245025635],
#                           'test_mean_f1/HSQC_H_NMR': [0.6905252933502197,
#                            0.6912462115287781,
#                            0.6903253793716431],
#                           'test_mean_f1/HSQC_C_NMR': [0.6988244652748108,
#                            0.6997169852256775,
#                            0.6978893280029297],
#                           'test_mean_f1/only_hsqc': [0.6842342615127563,
#                            0.6854256987571716,
#                            0.68315589427948],
#                           'test_mean_f1/only_1d': [0.6007643342018127,
#                            0.6030607223510742,
#                            0.5980668663978577],
#                           'test_mean_f1/only_H_NMR': [0.38949263095855713,
#                            0.38697996735572815,
#                            0.3836486339569092],
#                           'test_mean_f1/only_C_NMR': [0.5792590975761414,
#                            0.579662024974823,
#                            0.5754817128181458]})})

# %%
avg_results = {}
for exp_name, key_to_results in exp_name_to_key_to_results.items():
    avg_results[exp_name] = {key: (np.mean(val), np.std(val)) for key, val in key_to_results.items()}
avg_results
# Out:
# {'r6_16384_': {'test_mean_rank_1/all_inputs': (np.float64(0.2828357418378194),
#    np.float64(0.002324081036771461)),
#   'test_mean_rank_1/HSQC_H_NMR': (np.float64(0.263642817735672),
#    np.float64(0.0016202486808712638)),
#   'test_mean_rank_1/HSQC_C_NMR': (np.float64(0.28453083833058673),
#    np.float64(0.003114631202969392)),
#   'test_mean_rank_1/only_hsqc': (np.float64(0.2564523120721181),
#    np.float64(0.00366951568238073)),
#   'test_mean_rank_1/only_1d': (np.float64(0.17221675316492716),
#    np.float64(0.0026706949506146837)),
#   'test_mean_rank_1/only_H_NMR': (np.float64(0.02780511851112048),
#    np.float64(0.0014063673407912478)),
#   'test_mean_rank_1/only_C_NMR': (np.float64(0.14610673983891806),
#    np.float64(0.0019597511639115805)),
#   'test_mean_rank_5/all_inputs': (np.float64(0.6486220359802246),
#    np.float64(0.003009167702572203)),
#   'test_mean_rank_5/HSQC_H_NMR': (np.float64(0.6225940585136414),
#    np.float64(0.0036097498609407473)),
#   'test_mean_rank_5/HSQC_C_NMR': (np.float64(0.6523129741350809),
#    np.float64(0.0016981817297863802)),
#   'test_mean_rank_5/only_hsqc': (np.float64(0.6223479906717936),
#    np.float64(0.0021786551858436172)),
#   'test_mean_rank_5/only_1d': (np.float64(0.41426071524620056),
#    np.float64(0.0022535517329848815)),
#   'test_mean_rank_5/only_H_NMR': (np.float64(0.08368875583012898),
#    np.float64(0.0008918133679344659)),
#   'test_mean_rank_5/only_C_NMR': (np.float64(0.35711942116419476),
#    np.float64(0.002834975996855553)),
#   'test_mean_rank_10/all_inputs': (np.float64(0.7652559081713358),
#    np.float64(0.0038453716841221337)),
#   'test_mean_rank_10/HSQC_H_NMR': (np.float64(0.7413878043492635),
#    np.float64(0.0031942603782604876)),
#   'test_mean_rank_10/HSQC_C_NMR': (np.float64(0.7687554558118185),
#    np.float64(0.00524309523366352)),
#   'test_mean_rank_10/only_hsqc': (np.float64(0.7350721756617228),
#    np.float64(0.002622103460085952)),
#   'test_mean_rank_10/only_1d': (np.float64(0.5288713971773783),
#    np.float64(0.004788696540074836)),
#   'test_mean_rank_10/only_H_NMR': (np.float64(0.1292377511660258),
#    np.float64(0.0013129107289649338)),
#   'test_mean_rank_10/only_C_NMR': (np.float64(0.4615594943364461),
#    np.float64(0.0005454325139136083)),
#   'test_mean_mean_rank/all_inputs': (np.float64(423.24253336588544),
#    np.float64(86.30436616675772)),
#   'test_mean_mean_rank/HSQC_H_NMR': (np.float64(573.7354736328125),
#    np.float64(95.59741192596313)),
#   'test_mean_mean_rank/HSQC_C_NMR': (np.float64(385.1558024088542),
#    np.float64(63.47620715763857)),
#   'test_mean_mean_rank/only_hsqc': (np.float64(528.9336751302084),
#    np.float64(49.118232961063725)),
#   'test_mean_mean_rank/only_1d': (np.float64(1563.2912190755208),
#    np.float64(154.619111671569)),
#   'test_mean_mean_rank/only_H_NMR': (np.float64(18968.026692708332),
#    np.float64(166.50965571034234)),
#   'test_mean_mean_rank/only_C_NMR': (np.float64(3715.97216796875),
#    np.float64(200.95182832778525)),
#   'test_mean_cos/all_inputs': (np.float64(0.6884499390920004),
#    np.float64(0.0005570223985676173)),
#   'test_mean_cos/HSQC_H_NMR': (np.float64(0.678682267665863),
#    np.float64(0.00042178299398641894)),
#   'test_mean_cos/HSQC_C_NMR': (np.float64(0.6889035503069559),
#    np.float64(0.0004335293110689413)),
#   'test_mean_cos/only_hsqc': (np.float64(0.67153000831604),
#    np.float64(0.0007509504062172451)),
#   'test_mean_cos/only_1d': (np.float64(0.6050241986910502),
#    np.float64(0.0010753895209935458)),
#   'test_mean_cos/only_H_NMR': (np.float64(0.4227295517921448),
#    np.float64(0.0007959791505713081)),
#   'test_mean_cos/only_C_NMR': (np.float64(0.5782874425252279),
#    np.float64(0.0012968424271539536)),
#   'test_mean_f1/all_inputs': (np.float64(0.6984941164652506),
#    np.float64(0.0008007835280395403)),
#   'test_mean_f1/HSQC_H_NMR': (np.float64(0.6906989614168803),
#    np.float64(0.00039547727573712935)),
#   'test_mean_f1/HSQC_C_NMR': (np.float64(0.6988102595011393),
#    np.float64(0.0007462055498631086)),
#   'test_mean_f1/only_hsqc': (np.float64(0.6842719515164694),
#    np.float64(0.0009270269661745479)),
#   'test_mean_f1/only_1d': (np.float64(0.6006306409835815),
#    np.float64(0.0020409237659811245)),
#   'test_mean_f1/only_H_NMR': (np.float64(0.3867070774237315),
#    np.float64(0.002393592408223312)),
#   'test_mean_f1/only_C_NMR': (np.float64(0.57813427845637),
#    np.float64(0.0018828464215947514))}}

# %%
exp_name_key = list(avg_results.keys())[0]

# %%
for exp_name, key_to_results in avg_results[exp_name_key].items():
    print(exp_name)
    mean, std = key_to_results
    print(f" {mean:.4f} +/- {std:.4f}")
    print()
# Out:
# test_mean_rank_1/all_inputs
#  0.2828 +/- 0.0023
#
# test_mean_rank_1/HSQC_H_NMR
#  0.2636 +/- 0.0016
#
# test_mean_rank_1/HSQC_C_NMR
#  0.2845 +/- 0.0031
#
# test_mean_rank_1/only_hsqc
#  0.2565 +/- 0.0037
#
# test_mean_rank_1/only_1d
#  0.1722 +/- 0.0027
#
# test_mean_rank_1/only_H_NMR
#  0.0278 +/- 0.0014
#
# test_mean_rank_1/only_C_NMR
#  0.1461 +/- 0.0020
#
# test_mean_rank_5/all_inputs
#  0.6486 +/- 0.0030
#
# test_mean_rank_5/HSQC_H_NMR
#  0.6226 +/- 0.0036
#
# test_mean_rank_5/HSQC_C_NMR
#  0.6523 +/- 0.0017
#
# test_mean_rank_5/only_hsqc
#  0.6223 +/- 0.0022
#
# test_mean_rank_5/only_1d
#  0.4143 +/- 0.0023
#
# test_mean_rank_5/only_H_NMR
#  0.0837 +/- 0.0009
#
# test_mean_rank_5/only_C_NMR
#  0.3571 +/- 0.0028
#
# test_mean_rank_10/all_inputs
#  0.7653 +/- 0.0038
#
# test_mean_rank_10/HSQC_H_NMR
#  0.7414 +/- 0.0032
#
# test_mean_rank_10/HSQC_C_NMR
#  0.7688 +/- 0.0052
#
# test_mean_rank_10/only_hsqc
#  0.7351 +/- 0.0026
#
# test_mean_rank_10/only_1d
#  0.5289 +/- 0.0048
#
# test_mean_rank_10/only_H_NMR
#  0.1292 +/- 0.0013
#
# test_mean_rank_10/only_C_NMR
#  0.4616 +/- 0.0005
#
# test_mean_mean_rank/all_inputs
#  423.2425 +/- 86.3044
#
# test_mean_mean_rank/HSQC_H_NMR
#  573.7355 +/- 95.5974
#
# test_mean_mean_rank/HSQC_C_NMR
#  385.1558 +/- 63.4762
#
# test_mean_mean_rank/only_hsqc
#  528.9337 +/- 49.1182
#
# test_mean_mean_rank/only_1d
#  1563.2912 +/- 154.6191
#
# test_mean_mean_rank/only_H_NMR
#  18968.0267 +/- 166.5097
#
# test_mean_mean_rank/only_C_NMR
#  3715.9722 +/- 200.9518
#
# test_mean_cos/all_inputs
#  0.6884 +/- 0.0006
#
# test_mean_cos/HSQC_H_NMR
#  0.6787 +/- 0.0004
#
# test_mean_cos/HSQC_C_NMR
#  0.6889 +/- 0.0004
#
# test_mean_cos/only_hsqc
#  0.6715 +/- 0.0008
#
# test_mean_cos/only_1d
#  0.6050 +/- 0.0011
#
# test_mean_cos/only_H_NMR
#  0.4227 +/- 0.0008
#
# test_mean_cos/only_C_NMR
#  0.5783 +/- 0.0013
#
# test_mean_f1/all_inputs
#  0.6985 +/- 0.0008
#
# test_mean_f1/HSQC_H_NMR
#  0.6907 +/- 0.0004
#
# test_mean_f1/HSQC_C_NMR
#  0.6988 +/- 0.0007
#
# test_mean_f1/only_hsqc
#  0.6843 +/- 0.0009
#
# test_mean_f1/only_1d
#  0.6006 +/- 0.0020
#
# test_mean_f1/only_H_NMR
#  0.3867 +/- 0.0024
#
# test_mean_f1/only_C_NMR
#  0.5781 +/- 0.0019

# %%
numbers = np.array([0 , 0, 0])
numbers.mean(), numbers.std()
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
(torch.tensor([1,2,3]) == 0).all()
# Out:
# tensor(False)

# %%
key_to_results
# Out:
# (np.float64(0.57813427845637), np.float64(0.0018828464215947514))

# %%
# for k in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
#     print(k)
#     mean,std = (avg_results['r0_r6_'][k]['test/mean_rank_1'])
#     print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")

# %%
# print in latex format
'''deprecated !!!'''
# for table_name in  ["all_inputs", "HSQC_H_NMR", "HSQC_C_NMR", "only_hsqc", "only_1d", "only_H_NMR",  "only_C_NMR"]:
for table_name in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
    print(table_name)
    # print("\n\n")
    # print ("\\begin{table}[h]")
    # print("\centering")
    # print('\\begin{tabular}{|c|c|c|c|c|c|}')
    # print("\hline")
    # print("Model Input & Rank-1$\\uparrow$ & Rank-5$\\uparrow$ & Mean Rank$\\downarrow$ & Cosine Sim$\\uparrow$ & F1-score$\\uparrow$\\\\")
    for exp_name, key_to_results in avg_results.items():
        name = exp_name
        if name[:2]=="FP":
            name = "R"+name.split(" ")[-1][-2]+" FP"
        print(f'{name.replace("_", " ")}', end="")
        for key, (mean, std) in key_to_results.items():
            if table_name!=key.split("/")[-1]: 
                continue
            # print(key)
            # if "test_mean_rank_1" in key or "test/mean_rank_5" in key:
            print(key)
            print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")
            # elif "test_mean_mean_rank" in key :
            #     print(f' & {val+1:.2f}', end="")
            # else:
            #     print(f' & {val:.4f}', end="")
        # print(" \\\\")
        # print("\hline")
        
        
    # print('\end{tabular}')
    # print("\caption{for " + f'{table_name.replace("_", " ")}'+ ", which entropy-based FP to use}")
    # print('\label{table_name}')
    # print('\end{table}')
# Out:
# all_inputs
# r6 16384 test_mean_rank_1/all_inputs
# 28.28\%\textpm0.23\%
# test_mean_rank_5/all_inputs
# 64.86\%\textpm0.30\%
# test_mean_rank_10/all_inputs
# 76.53\%\textpm0.38\%
# test_mean_mean_rank/all_inputs
# 42324.25\%\textpm8630.44\%
# test_mean_cos/all_inputs
# 68.84\%\textpm0.06\%
# test_mean_f1/all_inputs
# 69.85\%\textpm0.08\%
# only_1d
# r6 16384 test_mean_rank_1/only_1d
# 17.22\%\textpm0.27\%
# test_mean_rank_5/only_1d
# 41.43\%\textpm0.23\%
# test_mean_rank_10/only_1d
# 52.89\%\textpm0.48\%
# test_mean_mean_rank/only_1d
# 156329.12\%\textpm15461.91\%
# test_mean_cos/only_1d
# 60.50\%\textpm0.11\%
# test_mean_f1/only_1d
# 60.06\%\textpm0.20\%
# HSQC_C_NMR
# r6 16384 test_mean_rank_1/HSQC_C_NMR
# 28.45\%\textpm0.31\%
# test_mean_rank_5/HSQC_C_NMR
# 65.23\%\textpm0.17\%
# test_mean_rank_10/HSQC_C_NMR
# 76.88\%\textpm0.52\%
# test_mean_mean_rank/HSQC_C_NMR
# 38515.58\%\textpm6347.62\%
# test_mean_cos/HSQC_C_NMR
# 68.89\%\textpm0.04\%
# test_mean_f1/HSQC_C_NMR
# 69.88\%\textpm0.07\%
# HSQC_H_NMR
# r6 16384 test_mean_rank_1/HSQC_H_NMR
# 26.36\%\textpm0.16\%
# test_mean_rank_5/HSQC_H_NMR
# 62.26\%\textpm0.36\%
# test_mean_rank_10/HSQC_H_NMR
# 74.14\%\textpm0.32\%
# test_mean_mean_rank/HSQC_H_NMR
# 57373.55\%\textpm9559.74\%
# test_mean_cos/HSQC_H_NMR
# 67.87\%\textpm0.04\%
# test_mean_f1/HSQC_H_NMR
# 69.07\%\textpm0.04\%
# only_C_NMR
# r6 16384 test_mean_rank_1/only_C_NMR
# 14.61\%\textpm0.20\%
# test_mean_rank_5/only_C_NMR
# 35.71\%\textpm0.28\%
# test_mean_rank_10/only_C_NMR
# 46.16\%\textpm0.05\%
# test_mean_mean_rank/only_C_NMR
# 371597.22\%\textpm20095.18\%
# test_mean_cos/only_C_NMR
# 57.83\%\textpm0.13\%
# test_mean_f1/only_C_NMR
# 57.81\%\textpm0.19\%
# only_H_NMR
# r6 16384 test_mean_rank_1/only_H_NMR
# 2.78\%\textpm0.14\%
# test_mean_rank_5/only_H_NMR
# 8.37\%\textpm0.09\%
# test_mean_rank_10/only_H_NMR
# 12.92\%\textpm0.13\%
# test_mean_mean_rank/only_H_NMR
# 1896802.67\%\textpm16650.97\%
# test_mean_cos/only_H_NMR
# 42.27\%\textpm0.08\%
# test_mean_f1/only_H_NMR
# 38.67\%\textpm0.24\%
# only_hsqc
# r6 16384 test_mean_rank_1/only_hsqc
# 25.65\%\textpm0.37\%
# test_mean_rank_5/only_hsqc
# 62.23\%\textpm0.22\%
# test_mean_rank_10/only_hsqc
# 73.51\%\textpm0.26\%
# test_mean_mean_rank/only_hsqc
# 52893.37\%\textpm4911.82\%
# test_mean_cos/only_hsqc
# 67.15\%\textpm0.08\%
# test_mean_f1/only_hsqc
# 68.43\%\textpm0.09\%
