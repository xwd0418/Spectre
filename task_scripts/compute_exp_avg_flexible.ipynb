# %%
import os, pickle, sys, torch, numpy as np


# table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/flexible_models_larger_no_jittering"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/stop_on_cosine/larger_flexible_models_3072dim"
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/rank_on_entire_set/flexible_models"
# '/root/gurusmart/MorganFP_prediction/reproduce_previous_works/all_2d1d_datasets/entropy_radius_exps_on_2d1d_datasets'
table_path = "/root/gurusmart/MorganFP_prediction/reproduce_previous_works/entropy_on_hashes/flexible_models_jittering_size_1/"
print_keys = [
    "test_mean_rank_1/",
    "test_mean_rank_5/",
    "test_mean_rank_10/",
    "test_mean_mean_rank",
    "test_mean_cos",
    "test_mean_f1", 
]

all_exps = os.listdir(table_path)
all_exps = sorted(all_exps)
# load pickles 
from collections import defaultdict
exp_name_to_key_to_results = defaultdict(lambda: defaultdict(list))
for exp in all_exps:
    # print(exp)
    if 'trial' in exp:
        trial_spelling = "trial"
    elif 'trail' in exp:
        trial_spelling = "trail"
        
    with open(f'{table_path}/{exp}/test_result.pkl', 'rb') as f:
        result = pickle.load(f)[0]
      

        
        for print_key in print_keys:
            for pickle_key in result:
                
                if print_key in pickle_key:
                    exp_name_to_key_to_results["_".join(exp.split(trial_spelling)[:-1])][pickle_key].append(result[pickle_key])
            # exp_name_to_key_to_results[exp][key].append(result[key])
            # print(key, result[key])
    
            
    
exp_name_to_key_to_results
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'r0_r6_': defaultdict(list,
#                          {'test_mean_rank_1/all_inputs': [0.5317421555519104,
#                            0.537319540977478,
#                            0.524114191532135],
#                           'test_mean_rank_1/HSQC_H_NMR': [0.48646652698516846,
#                            0.4902395009994507,
#                            0.4805610179901123],
#                           'test_mean_rank_1/HSQC_C_NMR': [0.5349409580230713,
#                            0.5335465669631958,
#                            0.5226377844810486],
#                           'test_mean_rank_1/only_hsqc': [0.4659612774848938,
#                            0.47211286425590515,
#                            0.46284449100494385],
#                           'test_mean_rank_1/only_1d': [0.278215229511261,
#                            0.27354001998901367,
#                            0.2522965967655182],
#                           'test_mean_rank_1/only_H_NMR': [0.038139764219522476,
#                            0.037647638469934464,
#                            0.036171261221170425],
#                           'test_mean_rank_1/only_C_NMR': [0.22555774450302124,
#                            0.2178477644920349,
#                            0.21120406687259674],
#                           'test_mean_rank_5/all_inputs': [0.8421915769577026,
#                            0.8410432934761047,
#                            0.8378444910049438],
#                           'test_mean_rank_5/HSQC_H_NMR': [0.8047900199890137,
#                            0.8036417365074158,
#                            0.800360918045044],
#                           'test_mean_rank_5/HSQC_C_NMR': [0.8399770259857178,
#                            0.8405511975288391,
#                            0.835629940032959],
#                           'test_mean_rank_5/only_hsqc': [0.7919947504997253,
#                            0.7898622155189514,
#                            0.7857611775398254],
#                           'test_mean_rank_5/only_1d': [0.5556922554969788,
#                            0.5506069660186768,
#                            0.5298556685447693],
#                           'test_mean_rank_5/only_H_NMR': [0.12278543412685394,
#                            0.11663385480642319,
#                            0.11146653443574905],
#                           'test_mean_rank_5/only_C_NMR': [0.4763779640197754,
#                            0.4676017165184021,
#                            0.46030184626579285],
#                           'test_mean_rank_10/all_inputs': [0.8982939720153809,
#                            0.8990321755409241,
#                            0.8941929340362549],
#                           'test_mean_rank_10/HSQC_H_NMR': [0.8653215169906616,
#                            0.8672900199890137,
#                            0.866879940032959],
#                           'test_mean_rank_10/HSQC_C_NMR': [0.8975557684898376,
#                            0.9012467265129089,
#                            0.8954232335090637],
#                           'test_mean_rank_10/only_hsqc': [0.8561351895332336,
#                            0.8586778044700623,
#                            0.85490483045578],
#                           'test_mean_rank_10/only_1d': [0.6555117964744568,
#                            0.6529691815376282,
#                            0.6301673054695129],
#                           'test_mean_rank_10/only_H_NMR': [0.16797900199890137,
#                            0.15985892713069916,
#                            0.1483759880065918],
#                           'test_mean_rank_10/only_C_NMR': [0.570620059967041,
#                            0.5633202195167542,
#                            0.5595472455024719],
#                           'test_mean_mean_rank/all_inputs': [150.8599090576172,
#                            97.18553161621094,
#                            183.71604919433594],
#                           'test_mean_mean_rank/HSQC_H_NMR': [307.6612548828125,
#                            239.94537353515625,
#                            314.61614990234375],
#                           'test_mean_mean_rank/HSQC_C_NMR': [182.28445434570312,
#                            103.1202392578125,
#                            177.93545532226562],
#                           'test_mean_mean_rank/only_hsqc': [274.12066650390625,
#                            254.21670532226562,
#                            448.2239074707031],
#                           'test_mean_mean_rank/only_1d': [1032.3231201171875,
#                            907.0580444335938,
#                            1464.7159423828125],
#                           'test_mean_mean_rank/only_H_NMR': [17649.900390625,
#                            18807.837890625,
#                            22083.966796875],
#                           'test_mean_mean_rank/only_C_NMR': [2534.583740234375,
#                            2763.812744140625,
#                            3115.732666015625],
#                           'test_mean_cos/all_inputs': [0.8929634690284729,
#                            0.8918958306312561,
#                            0.8934266567230225],
#                           'test_mean_cos/HSQC_H_NMR': [0.8782464861869812,
#                            0.876428484916687,
#                            0.8791154623031616],
#                           'test_mean_cos/HSQC_C_NMR': [0.8930594325065613,
#                            0.8920803666114807,
#                            0.8938496112823486],
#                           'test_mean_cos/only_hsqc': [0.8716263175010681,
#                            0.8704551458358765,
#                            0.8735644817352295],
#                           'test_mean_cos/only_1d': [0.773726761341095,
#                            0.7679078578948975,
#                            0.7639567852020264],
#                           'test_mean_cos/only_H_NMR': [0.5325008630752563,
#                            0.5286052227020264,
#                            0.5185994505882263],
#                           'test_mean_cos/only_C_NMR': [0.7367935180664062,
#                            0.729333221912384,
#                            0.7298117280006409],
#                           'test_mean_f1/all_inputs': [0.9054388403892517,
#                            0.9044890403747559,
#                            0.9060255885124207],
#                           'test_mean_f1/HSQC_H_NMR': [0.8931175470352173,
#                            0.8912343978881836,
#                            0.8939701914787292],
#                           'test_mean_f1/HSQC_C_NMR': [0.9053986072540283,
#                            0.9043256044387817,
#                            0.9064091444015503],
#                           'test_mean_f1/only_hsqc': [0.8871605396270752,
#                            0.885981023311615,
#                            0.8888939619064331],
#                           'test_mean_f1/only_1d': [0.7914606332778931,
#                            0.7841405868530273,
#                            0.7809862494468689],
#                           'test_mean_f1/only_H_NMR': [0.5364152193069458,
#                            0.532086193561554,
#                            0.5235495567321777],
#                           'test_mean_f1/only_C_NMR': [0.7607894539833069,
#                            0.751436173915863,
#                            0.7527228593826294]})})

# %%
avg_results = {}
for exp_name, key_to_results in exp_name_to_key_to_results.items():
    avg_results[exp_name] = {key: (np.mean(val), np.std(val)) for key, val in key_to_results.items()}
avg_results
# Out:
# {'r0_r6_': {'test_mean_rank_1/all_inputs': (np.float64(0.5310586293538412),
#    np.float64(0.005412683840818745)),
#   'test_mean_rank_1/HSQC_H_NMR': (np.float64(0.48575568199157715),
#    np.float64(0.003983066975267366)),
#   'test_mean_rank_1/HSQC_C_NMR': (np.float64(0.5303751031557719),
#    np.float64(0.005500645829514428)),
#   'test_mean_rank_1/only_hsqc': (np.float64(0.46697287758191425),
#    np.float64(0.0038508169476967366)),
#   'test_mean_rank_1/only_1d': (np.float64(0.2680172820885976),
#    np.float64(0.011278869810097455)),
#   'test_mean_rank_1/only_H_NMR': (np.float64(0.037319554636875786),
#    np.float64(0.000836452933430251)),
#   'test_mean_rank_1/only_C_NMR': (np.float64(0.2182031919558843),
#    np.float64(0.005865251451903318)),
#   'test_mean_rank_5/all_inputs': (np.float64(0.8403597871462504),
#    np.float64(0.0018393250115882908)),
#   'test_mean_rank_5/HSQC_H_NMR': (np.float64(0.8029308915138245),
#    np.float64(0.001876736788720335)),
#   'test_mean_rank_5/HSQC_C_NMR': (np.float64(0.838719387849172),
#    np.float64(0.0021971093277395053)),
#   'test_mean_rank_5/only_hsqc': (np.float64(0.7892060478528341),
#    np.float64(0.0025867965989027466)),
#   'test_mean_rank_5/only_1d': (np.float64(0.545384963353475),
#    np.float64(0.011175398284067295)),
#   'test_mean_rank_5/only_H_NMR': (np.float64(0.11696194112300873),
#    np.float64(0.0046267413318426456)),
#   'test_mean_rank_5/only_C_NMR': (np.float64(0.4680938422679901),
#    np.float64(0.00657226654587461)),
#   'test_mean_rank_10/all_inputs': (np.float64(0.8971730271975199),
#    np.float64(0.002128685439208147)),
#   'test_mean_rank_10/HSQC_H_NMR': (np.float64(0.8664971590042114),
#    np.float64(0.0008479944970761045)),
#   'test_mean_rank_10/HSQC_C_NMR': (np.float64(0.8980752428372701),
#    np.float64(0.002405640301415103)),
#   'test_mean_rank_10/only_hsqc': (np.float64(0.8565726081530253),
#    np.float64(0.0015710579269646234)),
#   'test_mean_rank_10/only_1d': (np.float64(0.646216094493866),
#    np.float64(0.011395582317734408)),
#   'test_mean_rank_10/only_H_NMR': (np.float64(0.15873797237873077),
#    np.float64(0.008042053803295174)),
#   'test_mean_rank_10/only_C_NMR': (np.float64(0.564495841662089),
#    np.float64(0.0045962572174283985)),
#   'test_mean_mean_rank/all_inputs': (np.float64(143.92049662272134),
#    np.float64(35.665101540027806)),
#   'test_mean_mean_rank/HSQC_H_NMR': (np.float64(287.4075927734375),
#    np.float64(33.6807495210561)),
#   'test_mean_mean_rank/HSQC_C_NMR': (np.float64(154.44671630859375),
#    np.float64(36.336702133974185)),
#   'test_mean_mean_rank/only_hsqc': (np.float64(325.5204264322917),
#    np.float64(87.1441339080947)),
#   'test_mean_mean_rank/only_1d': (np.float64(1134.6990356445312),
#    np.float64(238.89496136214578)),
#   'test_mean_mean_rank/only_H_NMR': (np.float64(19513.901692708332),
#    np.float64(1877.787846237868)),
#   'test_mean_mean_rank/only_C_NMR': (np.float64(2804.709716796875),
#    np.float64(239.0089820676338)),
#   'test_mean_cos/all_inputs': (np.float64(0.8927619854609171),
#    np.float64(0.0006409908225054958)),
#   'test_mean_cos/HSQC_H_NMR': (np.float64(0.8779301444689432),
#    np.float64(0.0011195284515618973)),
#   'test_mean_cos/HSQC_C_NMR': (np.float64(0.8929964701334635),
#    np.float64(0.0007236619245974866)),
#   'test_mean_cos/only_hsqc': (np.float64(0.8718819816907247),
#    np.float64(0.0012821896810160187)),
#   'test_mean_cos/only_1d': (np.float64(0.7685304681460062),
#    np.float64(0.004012799611499997)),
#   'test_mean_cos/only_H_NMR': (np.float64(0.5265685121218363),
#    np.float64(0.0058551094367359805)),
#   'test_mean_cos/only_C_NMR': (np.float64(0.731979489326477),
#    np.float64(0.0034096330741760616)),
#   'test_mean_f1/all_inputs': (np.float64(0.9053178230921427),
#    np.float64(0.0006331029060587005)),
#   'test_mean_f1/HSQC_H_NMR': (np.float64(0.8927740454673767),
#    np.float64(0.0011429892498326108)),
#   'test_mean_f1/HSQC_C_NMR': (np.float64(0.9053777853647867),
#    np.float64(0.0008507290432004336)),
#   'test_mean_f1/only_hsqc': (np.float64(0.8873451749483744),
#    np.float64(0.001196347348027511)),
#   'test_mean_f1/only_1d': (np.float64(0.7855291565259298),
#    np.float64(0.004387426995577507)),
#   'test_mean_f1/only_H_NMR': (np.float64(0.5306836565335592),
#    np.float64(0.005345194162866881)),
#   'test_mean_f1/only_C_NMR': (np.float64(0.7549828290939331),
#    np.float64(0.004139368657739828))}}

# %%
for exp_name, key_to_results in avg_results['r0_r6_'].items():
    print(exp_name)
    mean, std = key_to_results
    print(f" {mean:.4f} +/- {std:.4f}")
    print()
# Out:
# test_mean_rank_1/all_inputs
#  0.5311 +/- 0.0054
#
# test_mean_rank_1/HSQC_H_NMR
#  0.4858 +/- 0.0040
#
# test_mean_rank_1/HSQC_C_NMR
#  0.5304 +/- 0.0055
#
# test_mean_rank_1/only_hsqc
#  0.4670 +/- 0.0039
#
# test_mean_rank_1/only_1d
#  0.2680 +/- 0.0113
#
# test_mean_rank_1/only_H_NMR
#  0.0373 +/- 0.0008
#
# test_mean_rank_1/only_C_NMR
#  0.2182 +/- 0.0059
#
# test_mean_rank_5/all_inputs
#  0.8404 +/- 0.0018
#
# test_mean_rank_5/HSQC_H_NMR
#  0.8029 +/- 0.0019
#
# test_mean_rank_5/HSQC_C_NMR
#  0.8387 +/- 0.0022
#
# test_mean_rank_5/only_hsqc
#  0.7892 +/- 0.0026
#
# test_mean_rank_5/only_1d
#  0.5454 +/- 0.0112
#
# test_mean_rank_5/only_H_NMR
#  0.1170 +/- 0.0046
#
# test_mean_rank_5/only_C_NMR
#  0.4681 +/- 0.0066
#
# test_mean_rank_10/all_inputs
#  0.8972 +/- 0.0021
#
# test_mean_rank_10/HSQC_H_NMR
#  0.8665 +/- 0.0008
#
# test_mean_rank_10/HSQC_C_NMR
#  0.8981 +/- 0.0024
#
# test_mean_rank_10/only_hsqc
#  0.8566 +/- 0.0016
#
# test_mean_rank_10/only_1d
#  0.6462 +/- 0.0114
#
# test_mean_rank_10/only_H_NMR
#  0.1587 +/- 0.0080
#
# test_mean_rank_10/only_C_NMR
#  0.5645 +/- 0.0046
#
# test_mean_mean_rank/all_inputs
#  143.9205 +/- 35.6651
#
# test_mean_mean_rank/HSQC_H_NMR
#  287.4076 +/- 33.6807
#
# test_mean_mean_rank/HSQC_C_NMR
#  154.4467 +/- 36.3367
#
# test_mean_mean_rank/only_hsqc
#  325.5204 +/- 87.1441
#
# test_mean_mean_rank/only_1d
#  1134.6990 +/- 238.8950
#
# test_mean_mean_rank/only_H_NMR
#  19513.9017 +/- 1877.7878
#
# test_mean_mean_rank/only_C_NMR
#  2804.7097 +/- 239.0090
#
# test_mean_cos/all_inputs
#  0.8928 +/- 0.0006
#
# test_mean_cos/HSQC_H_NMR
#  0.8779 +/- 0.0011
#
# test_mean_cos/HSQC_C_NMR
#  0.8930 +/- 0.0007
#
# test_mean_cos/only_hsqc
#  0.8719 +/- 0.0013
#
# test_mean_cos/only_1d
#  0.7685 +/- 0.0040
#
# test_mean_cos/only_H_NMR
#  0.5266 +/- 0.0059
#
# test_mean_cos/only_C_NMR
#  0.7320 +/- 0.0034
#
# test_mean_f1/all_inputs
#  0.9053 +/- 0.0006
#
# test_mean_f1/HSQC_H_NMR
#  0.8928 +/- 0.0011
#
# test_mean_f1/HSQC_C_NMR
#  0.9054 +/- 0.0009
#
# test_mean_f1/only_hsqc
#  0.8873 +/- 0.0012
#
# test_mean_f1/only_1d
#  0.7855 +/- 0.0044
#
# test_mean_f1/only_H_NMR
#  0.5307 +/- 0.0053
#
# test_mean_f1/only_C_NMR
#  0.7550 +/- 0.0041

# %%
key_to_results
# Out:
# (np.float64(0.5310586293538412), np.float64(0.005412683840818745))

# %%
# for k in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
#     print(k)
#     mean,std = (avg_results['r0_r6_'][k]['test/mean_rank_1'])
#     print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")

# %%
# print in latex format
'''deprecated !!!'''
# for table_name in  ["all_inputs", "HSQC_H_NMR", "HSQC_C_NMR", "only_hsqc", "only_1d", "only_H_NMR",  "only_C_NMR"]:
for table_name in ['all_inputs', 'only_1d',  'HSQC_C_NMR', 'HSQC_H_NMR', 'only_C_NMR',  'only_H_NMR',  'only_hsqc' ]:
    print(table_name)
    # print("\n\n")
    # print ("\\begin{table}[h]")
    # print("\centering")
    # print('\\begin{tabular}{|c|c|c|c|c|c|}')
    # print("\hline")
    # print("Model Input & Rank-1$\\uparrow$ & Rank-5$\\uparrow$ & Mean Rank$\\downarrow$ & Cosine Sim$\\uparrow$ & F1-score$\\uparrow$\\\\")
    for exp_name, key_to_results in avg_results.items():
        name = exp_name
        if name[:2]=="FP":
            name = "R"+name.split(" ")[-1][-2]+" FP"
        print(f'{name.replace("_", " ")}', end="")
        for key, (mean, std) in key_to_results.items():
            if table_name!=key.split("/")[-1]: 
                continue
            # print(key)
            # if "test_mean_rank_1" in key or "test/mean_rank_5" in key:
            print(key)
            print(f"{mean*100:.2f}\%\\textpm{std*100:.2f}\% ")
            # elif "test_mean_mean_rank" in key :
            #     print(f' & {val+1:.2f}', end="")
            # else:
            #     print(f' & {val:.4f}', end="")
        # print(" \\\\")
        # print("\hline")
        
        
    # print('\end{tabular}')
    # print("\caption{for " + f'{table_name.replace("_", " ")}'+ ", which entropy-based FP to use}")
    # print('\label{table_name}')
    # print('\end{table}')
# Out:
# all_inputs
# r0 r6 test_mean_rank_1/all_inputs
# 73.95\%\textpm0.61\%
# test_mean_rank_5/all_inputs
# 94.14\%\textpm0.30\%
# test_mean_rank_10/all_inputs
# 96.81\%\textpm0.16\%
# test_mean_mean_rank/all_inputs
# 4717.26\%\textpm1963.20\%
# test_mean_cos/all_inputs
# 94.90\%\textpm0.23\%
# test_mean_f1/all_inputs
# 95.64\%\textpm0.20\%
# only_1d
# r0 r6 test_mean_rank_1/only_1d
# 67.25\%\textpm1.19\%
# test_mean_rank_5/only_1d
# 89.83\%\textpm0.63\%
# test_mean_rank_10/only_1d
# 93.74\%\textpm0.53\%
# test_mean_mean_rank/only_1d
# 7303.50\%\textpm1993.95\%
# test_mean_cos/only_1d
# 92.00\%\textpm0.39\%
# test_mean_f1/only_1d
# 93.01\%\textpm0.33\%
# HSQC_C_NMR
# r0 r6 test_mean_rank_1/HSQC_C_NMR
# 73.10\%\textpm1.25\%
# test_mean_rank_5/HSQC_C_NMR
# 93.56\%\textpm0.52\%
# test_mean_rank_10/HSQC_C_NMR
# 96.38\%\textpm0.38\%
# test_mean_mean_rank/HSQC_C_NMR
# 4860.27\%\textpm1000.61\%
# test_mean_cos/HSQC_C_NMR
# 94.57\%\textpm0.27\%
# test_mean_f1/HSQC_C_NMR
# 95.40\%\textpm0.24\%
# HSQC_H_NMR
# r0 r6 test_mean_rank_1/HSQC_H_NMR
# 64.65\%\textpm0.93\%
# test_mean_rank_5/HSQC_H_NMR
# 89.40\%\textpm0.48\%
# test_mean_rank_10/HSQC_H_NMR
# 93.35\%\textpm0.30\%
# test_mean_mean_rank/HSQC_H_NMR
# 17109.24\%\textpm5447.32\%
# test_mean_cos/HSQC_H_NMR
# 92.77\%\textpm0.19\%
# test_mean_f1/HSQC_H_NMR
# 93.87\%\textpm0.16\%
# only_C_NMR
# r0 r6 test_mean_rank_1/only_C_NMR
# 63.82\%\textpm2.06\%
# test_mean_rank_5/only_C_NMR
# 87.01\%\textpm1.26\%
# test_mean_rank_10/only_C_NMR
# 91.16\%\textpm0.96\%
# test_mean_mean_rank/only_C_NMR
# 36850.90\%\textpm2523.70\%
# test_mean_cos/only_C_NMR
# 90.54\%\textpm0.57\%
# test_mean_f1/only_C_NMR
# 91.94\%\textpm0.50\%
# only_H_NMR
# r0 r6 test_mean_rank_1/only_H_NMR
# 31.25\%\textpm1.16\%
# test_mean_rank_5/only_H_NMR
# 53.89\%\textpm0.61\%
# test_mean_rank_10/only_H_NMR
# 61.87\%\textpm0.56\%
# test_mean_mean_rank/only_H_NMR
# 149394.58\%\textpm6289.58\%
# test_mean_cos/only_H_NMR
# 79.06\%\textpm0.39\%
# test_mean_f1/only_H_NMR
# 80.20\%\textpm0.36\%
# only_hsqc
# r0 r6 test_mean_rank_1/only_hsqc
# 57.17\%\textpm0.22\%
# test_mean_rank_5/only_hsqc
# 84.05\%\textpm0.26\%
# test_mean_rank_10/only_hsqc
# 89.56\%\textpm0.17\%
# test_mean_mean_rank/only_hsqc
# 30262.36\%\textpm1718.62\%
# test_mean_cos/only_hsqc
# 90.66\%\textpm0.12\%
# test_mean_f1/only_hsqc
# 92.17\%\textpm0.12\%
