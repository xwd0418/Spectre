# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %%
targets = ['COC(=O)CCC(=O)c1ccc(OC2CCCCO2)cc1O', 'COC(=O)c1cccc(-c2nc3cccnc3[nH]2)c1', 
           'CON(C)C(=O)C1CCC(NC(=O)OC(C)(C)C)CC1', 'O=[N+]([O-])c1ccc(Cl)nc1Nc1ccc(O)cc1', 
           'NCC1=CC[C@@H](c2ccc(Cl)cc2Cl)[C@H]([N+](=O)[O-])C1', 
           'CCc1oc(-c2ccc(C(F)(F)F)cc2)nc1COC[C@@H]1CCC[C@H](COC(C)(C)C(=O)O)C1',
           'Cc1noc(C)c1NC(=O)Nc1ccc2nc(N[C@@H]3CCc4ccccc43)ccc2c1', 'Cc1cnc(N2CCN(C(=O)c3ccc(N4CCCS4(=O)=O)nc3C)CC2)c(C)c1']

# %%
def mol_with_atom_index(mol):
    for atom in mol.GetAtoms():
        atom.SetAtomMapNum(atom.GetIdx())
    return mol
for idx, target in enumerate(targets):
  print(f"Sample {idx}")
  mol = Chem.MolFromSmiles(target)
  display(mol_with_atom_index(mol))
# Out:
# Sample 0
# Sample 1
# Sample 2
# Sample 3
# Sample 4
# Sample 5
# Sample 6
# Sample 7

# %%
sample_0_searches = ['C1=C(COC(=O)CCC(c2ccc(O)cc2O)=O)CCO1', 'c1(O)ccc(C(=O)CCC(=O)OCC2=COCC2)c(O)c1', 
                     'C1=C(COC(=O)CCC(=O)c2ccc(O)cc2O)CCO1', 'C1=C(COC(=O)CCC(c2c(O)cc(O)cc2)=O)CCO1', 
                     'C1(COC(=O)CCC(c2ccc(O)cc2O)=O)=COCC1', 'C1=C(COC(CCC(=O)c2ccc(O)cc2O)=O)CCO1', 
                     'c1cc(O)cc(O)c1C(=O)CCC(=O)OCC1=COCC1', 'c1cc(O)cc(O)c1C(=O)CCC(OCC1=COCC1)=O', 
                     'C1=C(COC(=O)CCC(=O)c2c(O)cc(O)cc2)CCO1', 'C1(COC(=O)CCC(=O)c2ccc(O)cc2O)=COCC1']
print("Ground Truth: ")
mol = Chem.MolFromSmiles(targets[0])
display(mol_with_atom_index(mol))
for idx, output in enumerate(sample_0_searches):
  print(f"Predicted {idx}")
  mol = Chem.MolFromSmiles(output)
  display(mol_with_atom_index(mol))
# Out:
# Ground Truth:
# Predicted 0
# Predicted 1
# Predicted 2
# Predicted 3
# Predicted 4
# Predicted 5
# Predicted 6
# Predicted 7
# Predicted 8
# Predicted 9
